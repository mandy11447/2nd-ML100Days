# %% [markdown]
# # 作業1.
# 1. 你選的這組資料為何重要?
# 了解學生成績是否跟家長的教育程度、考試的事前準備影響
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# 資料來源:Exam Scores:http://roycekimmons.com/tools/generated_data/exams
#
# 3. 蒐集而來的資料型態為何
# gender:string
# race/ethnicity:string
# parental level of education:string
# lunch:string
# math score:intenger
# reading score:intenger
# writing score:intenger
#
# 4. 這組資料想解決的問題如何評估?
# 可使用羅吉斯回歸看出這兩個變因對於不同科目的影響
# 因為教育程度與事前準備的資料型態皆不是數字
# 轉換成數字後會是名目資料，故使用羅吉斯回歸。

# %% [markdown]
# # 作業2
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 利用數據分析，來限制一個地區內的車子數量，使車子不會供過於求、或是供不應求
# 若司機進入到已經滿額的地區，系統會建議他可以到最近未滿額的地區
#
# 假設:所有車子皆會開啟GPS系統，並使用GOOGLE MAP
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 車隊系統
# google map
# GPS
#
# 3. 蒐集而來的資料型態為何
# 時間
# 距離
# 地點
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 車隊一定會安裝自己的系統，並且會開啟導航

# %% [markdown]
# # 作業三

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 12.517

# %%
def mean_squared_error(y,yp):
     return sum(abs(y - yp)**2)/len(y)

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 261.096
# The Mean absolute error is 12.517
